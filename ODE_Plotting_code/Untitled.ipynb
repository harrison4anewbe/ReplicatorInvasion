# %%
import csv
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

path = '../dataset/RockyIntertidalAdjacencyMatrix.csv'



# Load the CSV file using numpy
data = np.loadtxt(path)

import csv

datafreq = []
for line in data:
    for i in range(len(line)):
        if line[i]:
            datafreq.append(i)
tmp= Counter(datafreq)
tmp.most_common()
# Out:
# [(37, 26),
#  (27, 25),
#  (28, 19),
#  (69, 18),
#  (20, 17),
#  (87, 16),
#  (51, 15),
#  (78, 14),
#  (105, 14),
#  (10, 13),
#  (104, 13),
#  (61, 13),
#  (132, 13),
#  (3, 12),
#  (52, 12),
#  (91, 12),
#  (23, 11),
#  (71, 11),
#  (75, 11),
#  (88, 11),
#  (0, 10),
#  (44, 10),
#  (31, 10),
#  (39, 10),
#  (24, 10),
#  (74, 10),
#  (4, 9),
#  (45, 9),
#  (47, 9),
#  (26, 9),
#  (101, 9),
#  (58, 9),
#  (121, 9),
#  (110, 9),
#  (8, 8),
#  (9, 8),
#  (50, 8),
#  (17, 8),
#  (100, 8),
#  (72, 8),
#  (98, 8),
#  (99, 8),
#  (97, 8),
#  (1, 7),
#  (43, 7),
#  (15, 7),
#  (73, 7),
#  (76, 7),
#  (133, 7),
#  (136, 7),
#  (125, 7),
#  (81, 7),
#  (82, 7),
#  (131, 7),
#  (2, 6),
#  (41, 6),
#  (42, 6),
#  (46, 6),
#  (30, 6),
#  (12, 6),
#  (19, 6),
#  (25, 6),
#  (32, 6),
#  (57, 6),
#  (77, 6),
#  (84, 6),
#  (63, 6),
#  (66, 6),
#  (135, 6),
#  (64, 6),
#  (40, 5),
#  (29, 5),
#  (102, 5),
#  (14, 5),
#  (35, 5),
#  (16, 5),
#  (21, 5),
#  (62, 5),
#  (122, 5),
#  (60, 5),
# ...

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# Generate a random adjacency matrix with 150 nodes
adj_matrix = data#np.random.randint(0, 2, size=(150, 150))

# Create a graph from the adjacency matrix
G = nx.DiGraph(adj_matrix)

# Set the position of each node manually
pos = nx.circular_layout(G) #{i: (np.random.rand(), np.random.rand()) for i in range(150)}

# Draw the graph with nodes placed at the specified positions
nx.draw(G, pos, node_size=10, alpha=0.1)

# Display the plot
plt.show()
